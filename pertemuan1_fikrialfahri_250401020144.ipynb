# %% [markdown]
# <a href="https://colab.research.google.com/github/ffahrialfikri/Data-Science-2026/blob/main/pertemuan1_fikrialfahri_250401020144.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Fikri Alfahri
# Kelas: IF405
# NIM: 250401020144

# %%
# Basic
print("hello fikri")

print("------------------")

# Variabel
nama = "fikri alfahri"
angkatan = 2025

print(f"hallo! nama saya, {nama} angkatan {angkatan}")

print("------------------")

# Perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")

print("------------------")

# fungsi
def perkenalan (nama, prodi, angkatan):
  return f" {nama} | {prodi} | {angkatan}"
print(perkenalan("fikri", "PJJ Informatika", 2025))

print("------------------")

def penjumlahan (bil1, bil2):
  return (bil1 + bil2)
hasil = penjumlahan(10, 10)
print("Hasil penjumlahan:", hasil)
# Out:
# hello fikri
# ------------------
# hallo! nama saya, fikri alfahri angkatan 2025
# ------------------
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub
# ------------------
#  fikri | PJJ Informatika | 2025
# ------------------
# Hasil penjumlahan: 20

# %% [markdown]
# ## Rangkuman Notebook
#
# Notebook ini berisi demonstrasi dasar-dasar pemrograman Python, meliputi:
#
# *   **Dasar `print`**: Menampilkan teks ke konsol.
# *   **Penggunaan Variabel**: Contoh deklarasi dan penggunaan variabel untuk menyimpan nama dan angkatan.
# *   **Perulangan (`for loop`)**: Iterasi melalui daftar `tools` (Python, Colab, Jupyter, GitHub) dan menampilkan setiap item.
# *   **Fungsi**: Dua contoh fungsi disediakan:
#     *   `perkenalan`: Menerima nama, program studi, dan angkatan untuk membuat string perkenalan.
#     *   `penjumlahan`: Menerima dua bilangan dan mengembalikan hasil penjumlahannya.
